# %% [markdown]
#  # [![](https://img.shields.io/badge/Phiên%20bản-v2.5.0-0075ff)](https://stablediffusion.vn/update/) [![](https://img.shields.io/badge/Hướng%20dẫn%20-Sử%20dụng%20WebUI-5858e6)](https://stablediffusion.vn/huong-dan-chung/) [![](https://img.shields.io/badge/Tra%20cứu-Tính%20năng%20WebUI-5858e6)](https://stablediffusion.vn/webui-catalog/) [![](https://img.shields.io/badge/Thiết%20kế-stablediffusion.vn-0075ff)](https://stablediffusion.vn) [![](https://img.shields.io/badge/Group-Support-0075ff)](https://www.facebook.com/groups/stablediffusion.vn) [![](https://img.shields.io/discord/813085864355037235?color=blue&label=Discord&logo=Discord)](https://discord.gg/5SEtApPeyG) [![](https://img.shields.io/badge/Donate-SDVN-green)](https://stablediffusion.vn/donate/)
#
#  [![](https://img.shields.io/badge/Bộ%20công%20cụ-Đầy%20đủ-0075ff)](https://stablediffusion.vn/bo-cong-cu/) [![](https://img.shields.io/badge/Tools-Downloads-green)](https://colab.research.google.com/drive/1bbprkrT2gBb_JS8Noi3yxIEEFlV_PWw9) [![](https://img.shields.io/badge/Check-Gradio%20Sever-orange)](https://status.gradio.app) [![](https://img.shields.io/badge/Hướng%20dẫn%20-SD%20Nhập%20Môn-5858e6)](https://stablediffusion.vn/nhap-mon-stable-diffusion/) [![](https://img.shields.io/badge/Thư%20viện-Tài%20nguyên-green)](https://bit.ly/sdvn-lib) [![](https://img.shields.io/badge/Khoá%20học-SD-red)](https://hungdiffusion.com/)
#
# ___
# ### 🔴 `Hiện tại các phiên bản không sử dụng với Colab Free`
# ### 💡 Bỏ Prune để sử dụng phiên bản chuẩn - tải lâu hơn 5phút
# ### 💡 Link rút gọn để dùng tất cả các công cụ của SDVN : `sdvn.me`
# ### 💡 Hướng dẫn cơ bản (Mở ô ẩn để đọc):

# %% [markdown]
# ---
# ## 💡 Hướng dẫn sử dụng :
# + Một số lưu ý phiên bản :
#     - Version AutoDrive : Sẽ tải tất cả dữ liệu automatic1111 mới nhất lưu trữ tại drive, thư mục lưu trữ trên drive có thể tuỳ chỉnh tại setting ForderNamePatch. Từ lần sau sẽ kết nối trực tiếp drive mà không phải tải lại.
#     - Controlnet "Drive", sẽ load model Controlnet trong thư mục ControlnetModel trên drive thay vì tải controlnet.
#     - Version Fooocus sẽ lưu ảnh và load lora trong drive. Tích chọn SaveFromMyDrive nếu muốn load model sẵn cõ trong drive, tuy nhiên cần lưu ý drive cần sẵn khoảng 10GB dữ liệu trống.
#     - Để Swap Version : Vào thời gian chạy ấn khởi động lại thời gian chạy => Thay đổi version => Tích chọn swapversion => Chạy tiếp run all như bình thường
#     - Các Version A-1.3, A-1.42, A-1.51 không hoạt động với SDXL
#     - Option Prune : Giúp loại bỏ tối đa các tài nguyên cần tải, giúp nhanh chóng cài đặt chương trình
#     - Option Extension : Giúp lựa chọn Extension sử dụng đối với các Version A -
#     - Option Controlnet : Sẽ tải các controlnet về sử dụng với tất cả version trừ SDXL (Chưa có controlnet dùng đc), tuy nhiên sẽ tốn rất nhiều tài nguyên, hãy cân nhắc khi chọn Extra
#     - Option Setting : Chứa các tuỳ chọn để update hoặc reset các setting, khi gặp lỗi không mong muốn, hãy thử reset setting
#     - Option NoLibrary : Sẽ loại bỏ việc tải thêm thư viện model, lora có sẵn, nếu chọn Prune, thì tuỳ chọn này mặc định đc chọn
#     - Option Swapversion : Sẽ giúp thay đổi Version sử dụng mà không cần ngắt phiên, nếu ko chọn, việc chạy lại phần một chỉ tải thêm các tài nguyên chưa có từ phiên trước
#     - Option QRControlnet : Chỉ có tác dụng với các Version A - Giúp tải thêm controlnet, extension dùng trong việc tạo QR art
#     - Option APIPhotoshop : Sẽ giúp cài đặt thêm Extension, giúp link sử dụng có thể API được với Photoshop
#     - Comfy UI : Chỉ có tác dụng với option Prune, Controlnet
#     - DevMode : Giúp sử dụng trước các thay đổi của A1111
# ___
#
# + B1 : Tuỳ chọn phiên bản sử dụng,tuỳ chọn thêm model nếu chưa có sẵn model trên drive ( Các model này chỉ lưu vào bộ nhớ tạm, không chiếm dụng drive ). Trường hợp không có model, SDver1.5 sẽ được tự động tải về colab.
# + B2 :  **Ctr+F9** (Hoặc vào thời gian chạy => Chạy tất cả)
# + B3 : Đồng ý " Vẫn chạy " khi được cảnh báo
# + B4 : Đồng ý kết nối với drive khi được hỏi
# + B5 : Đợi 5 - 7 phút cho tới khi chương trình chạy tới lúc xuất hiện  đường link ở kết quả của phần 2
# + B6 : Sử dụng 1 link đuôi gradio để truy cập WebUI và sử dụng | Riêng đối với comfyUI Version, đường link sử dụng xuất hiện ngay trên cùng của phần 2 có đuôi cloudflare.
# ---
# ## 💡 Hướng dẫn cài đặt là lấy API với Photoshop Extension :
#
# + Tương thích với bản PTS 2023 mới nhất
# + Cài đặt Extension : [GitHub](https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin/releases/tag/v1.2.2) , vào link trên, tải file .zip or ccx , giải nén vào thư mục /Photoshop/Plugins và khởi động PTS
# + Chạy chương trình tới khi nhận link giao diện UI ( Hiện tại phiên bản ver2-16 tương thích hoàn toàn, phiên bản ver2-23, ver2update thì có thể xuất hiện lỗi )
# + Copy 1 trong các đường link sử dụng UI ( Ưu tiên nhất cloudflare ) vào Extension ( phần setting ) trên PTS để sử dụng.
#
# ---
# ## 💡 Lưu dữ liệu và tải về :
# - Lưu model tuỳ chọn trên drive tại thư mục : /MyDrive/SD-Data/Model
# - Lưu lora tuỳ chọn trên drive tại thư mục : /MyDrive/SD-Data/Lora
# - Lưu textual tuỳ chọn trên drive tại thư mục : /MyDrive/SD-Data/Embeddings
# - Lưu wildcards cho Dynamic Prompt : /MyDrive/SD-Data/wildcards
# - Lưu Hypernetworks trên drive tại thư mục : /MyDrive/SD-Data/Hypernetworks
# - Lưu model AnimateDiff tại thư mục nếu muốn sử dụng : /MyDrive/SD-Data/AnimateDiff, tải [tại đây](https://huggingface.co/guoyww/animatediff/tree/main)
# - Lưu lora AnimateDiff tại thư mục : /MyDrive/SD-Data/Lora/AnimateDiff, tải [tại đây](https://huggingface.co/guoyww/animatediff/tree/main)
# - Tools hỗ trợ download model về drive : [Download tools](https://colab.research.google.com/drive/1bbprkrT2gBb_JS8Noi3yxIEEFlV_PWw9#scrollTo=gAg03nKay-G8)
# ---
# ## 💡 Lưu ý :
#
# 🚩 Nếu không tự động nhận thư mục trong drive, hãy check kỹ lại đường dẫn và tài khoản
#
# 🚩 Nếu không kết nối được GPU ( Hết thời gian dùng GPU miễn phí trong ngày / Hôm sau mới hồi lại được ), hãy đổi tài khoản google khác để sử dụng hoặc nâng cấp pro
#
# 🚩 Chia sẻ thư mục SD-Data và tạo đường dẫn đến drive của tôi đối với tài khoản khác nếu muốn dùng chung dữ liệu và cài đặt ( Lưu ý tk phụ nếu đã có thư mục SD-Data hãy xoá đi, chỉ để đường dẫn lối tắt của tk chính thôi )

# %% [markdown]
# # 🚀 StableDiffusion.VN
#
# 🟡 `Hỗ trợ thêm 2 sever mới phòng trường hợp gradio bị down sever`
#
# 🟡 `Cập nhật thêm các Controlnet mới - Bỏ Prune để cài đặt thêm`
#
# 🟡 `Thư viện lora hỗ trợ thêm TCD, HyperSD`
#
# 🟡 `Thêm chế độ ExtraNote trong ComfyUI Ver`
#
# 💡 `Hỗ trợ cài đặt note bất kỳ thông qua tệp ComfyCustomNote.txt trong thư mục wildcard trong drive`

# %%
#@title # ⚙️ 1.Tuỳ chọn phiên bản
#Cài môi trường
Version = "A1111-update"   #@param ["AutoDrive","ComfyUI","Invoke","Kohya","Fooocus", "A-1.61","A-1.7", "A-1.8", "A-Forge", "A1111-update"]
Extensions = "base"  #@param ["base","plus","video","train"]
Controlnet = "base"  #@param ["drive","base","extra","XL", "XL-Base"]
Setting = "none" #@param ["none", "update" , "resetall"]

Prune = True  #@param {type:"boolean"}
SwapVersion = False  #@param {type:"boolean"}
#@markdown ## ⚙️ Version ComfyUI
ExtraNote = False  #@param {type:"boolean"}
#@markdown ## ⚙️ Version Automatic
#@markdown <br> [![](https://img.shields.io/badge/Lấy%20token-Ngrok-red)](https://dashboard.ngrok.com/get-started/your-authtoken)
Ngroktoken = "" #@param {type:"string"}
NoLibrary = False  #@param {type:"boolean"}
DeforumMode = False  #@param {type:"boolean"}
PhotoshopAPI = False  #@param {type:"boolean"}
DevMode = False  #@param {type:"boolean"}
#@markdown ## ⚙️ Version AutoDrive
ForderNamePatch = "AutomaticSDVN" #@param {type:"string"}
Update = False #@param {type:"boolean"}
#@markdown ## ⚙️ Version Invoke
DriveData = False #@param {type:"boolean"}
DriveDataPatch = "InvokeData" #@param {type:'string'}

from google.colab import drive
drive.mount('/content/drive')

# %cd /content
# !wget -nc https://raw.githubusercontent.com/phamhungd/SDCustom/main/Start.ipynb -qq
# %run Start.ipynb

#Library

if Version == "Kohya"  or Version == "Fooocus" or Version =="Invoke":
  Controlnet = "none"
  Prune = True
with open("/content/command/sdvn.txt", "r") as file:
    sdvn = file.readlines()
if Prune == True :
  line = 8
else :
  line = 9
if Controlnet == "base" :
  subprocess.run(sdvn[line],shell=True)
if Controlnet == "extra" :
  subprocess.run(sdvn[line],shell=True)
  subprocess.run(sdvn[12],shell=True)
if Controlnet == "XL" :
  subprocess.run(sdvn[135],shell=True)
if Controlnet == "XL-Base" :
  subprocess.run(sdvn[135],shell=True)
  subprocess.run(sdvn[line],shell=True)


#A1111

if Version =="A-1.61" or Version =="A-1.7" or Version =="A-1.8" or Version =="A-Forge" or Version =="A1111-update":
  if SwapVersion == True :
    # !rm -r /content/SDVN

  if Version=="A-1.61" :
      subprocess.run(sdvn[1],shell=True)
  if Version=="A-1.7" :
      subprocess.run(sdvn[34],shell=True)
  if Version=="A-1.8" :
      subprocess.run(sdvn[35],shell=True)
  if Version=="A-Forge" :
      subprocess.run(sdvn[52],shell=True)
  if Version=="A1111-update" :
      if DevMode == False :
        subprocess.run(sdvn[11],shell=True)
      else :
        subprocess.run(sdvn[5],shell=True)
  if Prune == True :
    with open("/content/command/baseprund.txt", "r") as file:
      exs = file.readlines()
      for ex in exs :
        subprocess.run(ex,shell=True)
  else :
    with open("/content/command/exbase.txt", "r") as file:
      exs = file.readlines()
      for ex in exs :
        subprocess.run(ex,shell=True)

  if Extensions=="plus" :
    with open("/content/command/explus.txt", "r") as file:
      exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)

  if Extensions=="video" :
    with open("/content/command/exvideo.txt", "r") as file:
      exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)

  if Extensions=="train" :
    with open("/content/command/extrain.txt", "r") as file:
      exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)

  if DeforumMode == True and Extensions == "video":
    lines=[71,72,73,74,75,76,77,78,79]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  if PhotoshopAPI == True :
    # !git clone https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin.git /content/SDVN/extensions/Auto-Photoshop

  # %cd /content/SDVN

  #Controlnet
  # !mkdir /content/SDVN/models/ControlNet
  if Controlnet != "drive" :
    # !ln -s /content/drive/MyDrive/SD-Data/ControlnetModel /content/SDVN/models/ControlNet
  if Controlnet == "base" or Controlnet == "extra":
    # !{sdvn[10]}
    if Controlnet == "extra" :
      # !{sdvn[13]}
  if Controlnet == "XL" :
    # !{sdvn[136]}
  if Controlnet == "XL-Base" :
    # !{sdvn[136]}
    # !{sdvn[10]}

  # Library

  lines=[15,16,17,18,19,20,21,22]
  for line in lines :
    subprocess.run(sdvn[line],shell=True)

  if Version=="A1111-update" or Version=="A-Forge":
    if DevMode==False :
      lines=[23,24,25,26,27,28,29]
      for line in lines :
        subprocess.run(sdvn[line],shell=True)
    else :
      lines=[23,24,25,31,27,28,29]
      for line in lines :
        subprocess.run(sdvn[line],shell=True)
  if Version=="A-Forge":
    # !rm -r /content/SDVN/extensions/sd-webui-controlnet
    # !git clone https://github.com/layerdiffusion/sd-forge-layerdiffusion /content/SDVN/extensions/sd-forge-layerdiffusion
  #Custom

  lines=[33]
  for line in lines :
    subprocess.run(sdvn[line],shell=True)

  if Setting == "update" :
    print("Update tệp style")
    lines=[44,45]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

  if Setting == "resetall" :
    print("Reset all setting file")
    lines=[47,48,49,81]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  if NoLibrary != True :
    lines=[51,53,54,56,58,61,62]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  else:
    lines=[53,54]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

if Version == "AutoDrive" :
  with open("/content/command/driveex.txt", "r") as file:
    driveexs = file.readlines()

  if not os.path.exists(f"/content/drive/MyDrive/{ForderNamePatch}"):

    print("Cài đặt lần đầu")

    # !git clone https://github.com/phamhungd/SDVN /content/drive/MyDrive/{ForderNamePatch}
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/drive/MyDrive/{ForderNamePatch}/models/Stable-diffusion -o VAE84.vae.pt
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/GuoZovya/resolve/main/4x-UltraSharp.ckpt -d /content/drive/MyDrive/{ForderNamePatch}/models/ESRGAN -o 4x-UltraSharp.pth
    # %cd /content/drive/MyDrive/{ForderNamePatch}/extensions
    for driveex in driveexs :
      subprocess.run(driveex,shell=True)
    # %cd /content/drive/MyDrive/{ForderNamePatch}
    # !sed -i -e 's/    start()/    #start()/g' launch.py
    # !sed -i -e 's/checkout {commithash}/checkout --force {commithash}/g' modules/launch_utils.py
    # !python launch.py --skip-torch-cuda-test
    # !git reset --hard
    lines=[145,146,147,148,149,150,151,152]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
    # !rm -r /content/drive/MyDrive/{ForderNamePatch}/extensions/sd-dynamic-prompts/wildcards
    # !ln -s /content/drive/MyDrive/SD-Data/wildcards /content/drive/MyDrive/{ForderNamePatch}/extensions/sd-dynamic-prompts/

  # %cd /content/

  controlnetpath = f"/content/drive/MyDrive/{ForderNamePatch}/{sdvn[68]}"
  controlnetpath = controlnetpath.replace("\n", "")
  # !rm {controlnetpath}/Basecontrolnet
  # !rm {controlnetpath}/Extracontrolnet
  # !rm {controlnetpath}/XLControlnet
  if Controlnet == "base" or Controlnet == "extra" :
    # !ln -s /content/Basecontrolnet {controlnetpath}
  if Controlnet == "extra" :
    # !ln -s /content/Basecontrolnet {controlnetpath}
    # !ln -s /content/Extracontrolnet {controlnetpath}
  if Controlnet == "XL" :
    # !ln -s /content/XLControlnet {controlnetpath}
  if Controlnet == "XL-Base" :
    # !ln -s /content/XLControlnet {controlnetpath}
    # !ln -s /content/Basecontrolnet {controlnetpath}

  print("Chạy chương trình")

  # %cd /content/drive/MyDrive/{ForderNamePatch}
  if Update == True :
    # !git reset --hard
    # !rm  /content/drive/MyDrive/{ForderNamePatch}/webui.sh
    # !git pull
    # !sed -i -e 's/    start()/    #start()/g' launch.py
    # !sed -i -e 's/checkout {commithash}/checkout --force {commithash}/g' modules/launch_utils.py
    # !python launch.py --skip-torch-cuda-test
    # !git reset --hard
    lines=[145,146,147,148,149,150,151,152]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

#ComfyUI

if Version == "ComfyUI" :
  print('[1;32mCài đặt ComfyUI...')
  time.sleep(4)
  with capture.capture_output() as cap:
    def inf(msg, style, wdth):
        inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth))
        display(inf)
    if SwapVersion == True :
      # !rm -r /content/ComfyUI
    lines=[88,89]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
    # %cd /content
    subprocess.run(sdvn[92],shell=True)
    if NoLibrary != True :
      lines=[51,56,58,60]
      for line in lines :
        subprocess.run(sdvn[line],shell=True)
    # %cd /content/ComfyUI
    subprocess.run(sdvn[94],shell=True)
    # %cd /content/ComfyUI/custom_nodes

    if Prune == True :
      with open("/content/command/comfynoteprune.txt", "r") as file:
        exs = file.readlines()
    else :
      with open("/content/command/comfynote.txt", "r") as file:
        exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)
    if ExtraNote == True :
      with open("/content/command/comfynoteplus.txt", "r") as file:
        exs = file.readlines()
      for ex in exs :
        subprocess.run(ex,shell=True)
    #custom note

    # %cd /content/

    # !ln -s /content/drive/MyDrive/SD-Data/Model /content/ComfyUI/models/checkpoints
    # !ln -s /content/drive/MyDrive/SD-Data/Lora /content/ComfyUI/models/loras
    # !ln -s /content/drive/MyDrive/SD-Data/Embeddings /content/ComfyUI/models/embeddings
    # !ln -s /content/drive/MyDrive/SD-Data/Hypernetworks /content/ComfyUI/models/hypernetworks
    # !ln -s /content/drive/MyDrive/SD-Data/wildcards /content/ComfyUI/
    # !ln -s /content/drive/MyDrive/SD-Data/AnimateDiffModel /content/ComfyUI/custom_nodes/ComfyUI-AnimateDiff-Evolved/models
    # !ln -s /content/drive/MyDrive/SD-Data/Lora/AnimateDiffLora /content/ComfyUI/custom_nodes/ComfyUI-AnimateDiff-Evolved/motion_lora

    if Controlnet == "XL" :
      # !ln -s /content/XLControlnet /content/ComfyUI/models/controlnet
    if Controlnet == "XL-Base" :
      # !ln -s /content/XLControlnet /content/ComfyUI/models/controlnet
      # !ln -s /content/Basecontrolnet /content/ComfyUI/models/controlnet
    if Controlnet == "base" :
      # !ln -s /content/Basecontrolnet /content/ComfyUI/models/controlnet
    if Controlnet == "extra" :
      # !ln -s /content/Basecontrolnet /content/ComfyUI/models/controlnet
      # !ln -s /content/Extracontrolnet /content/ComfyUI/models/controlnet
    # !ln -s /content/drive/MyDrive/SD-Data/ControlnetModel /content/ComfyUI/models/controlnet

    # !rm -r /content/ComfyUI/output
    time = datetime.now().date()
    # !mkdir -p /content/drive/MyDrive/SD-Data/Export/ComfyUI/{time}
    # !ln -s /content/drive/MyDrive/SD-Data/Export/ComfyUI/{time} /content/ComfyUI/output
    # !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /content/cloudflared-linux-amd64 && chmod 777 /content/cloudflared-linux-amd64
    # %cd /content/ComfyUI

  clear_output()
  inf('\u2714 Done','success', '150px')

if Version == "Kohya" :
  from google.colab import drive
  drive.mount('/content/drive')
  print('[1;32mCài đặt Kohya...')
  time.sleep(4)
  with capture.capture_output() as cap:
    def inf(msg, style, wdth):
        inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth))
        display(inf)

    # !pip install dadaptation==3.1 diffusers[torch]==0.17.1 easygui==0.98.3 einops==0.6.0 fairscale==0.4.13 ftfy==6.1.1 gradio==3.36.1 huggingface-hub==0.14.1
    # !pip install lion-pytorch==0.0.6 lycoris_lora==1.8.0.dev6 open-clip-torch==2.20.0 prodigyopt==1.0 pytorch-lightning==1.9.0 safetensors==0.3.1 timm==0.6.12
    # !pip install tk==0.1.0 transformers==4.30.2 voluptuous==0.13.1 wandb==0.15.0 xformers==0.0.20 omegaconf

    # !git clone -b 0.41.0 https://github.com/TimDettmers/bitsandbytes
    # %cd /content/bitsandbytes
    # !CUDA_VERSION=118 make cuda11x
    # !python setup.py install
    # %cd /content
    # !git clone -b https://github.com/phamhungd/KohyaUI
    # %cd /content/KohyaUI

  clear_output()
  inf('\u2714 Done','success', '150px')

if Version =="Fooocus" :
  # !pip install pygit2==1.12.2
  # %cd /content
  # !git clone https://github.com/lllyasviel/Fooocus
  # %cd /content/Fooocus
  # !rm -r /content/Fooocus/outputs
  # !ln -s /content/drive/MyDrive/SD-Data/Export/Fooocus /content/Fooocus/outputs
  # !rm -r /content/Fooocus/models/loras
  # !ln -s /content/drive/MyDrive/SD-Data/Lora /content/Fooocus/models/loras
  # !ln -s /content/WC-SDVN /content/Fooocus/wildcards/
  # !rm -r /content/Fooocus/models/checkpoints
  # !ln -s /content/drive/MyDrive/SD-Data/Model /content/Fooocus/models/checkpoints
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/338512 -d /content/Fooocus -o Leosam-HelloWorldv5.safetensors
  # !ln -s /content/Fooocus/Leosam-HelloWorldv5.safetensors /content/Fooocus/models/checkpoints
  # !mkdir /content/DownloadModel
  # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/phamhungd/SDCustom/main/Fooocusconfig.txt -d  /content/Fooocus -o config.txt


if Version == "Invoke" :
  from IPython.display import clear_output
  import os
  import shlex
  import subprocess
  from pathlib import Path
  from typing import Union
  from IPython.display import clear_output

  # %cd /content
  # !git clone https://github.com/ai-marat/InvokeAI
  # !pip install -q dependency_injector diffusers einops eventlet facexlib flask_cors flask_socketio flaskwebgui getpass_asterisk huggingface-hub
  # !pip install -q kornia omegaconf pudb pyreadline3 pytorch-lightning realesrgan streamlit taming-transformers-rom1504 test-tube torch-fidelity
  # !pip install -q torchmetrics transformers picklescan
  # !pip install -q pillow xformers==0.0.20 triton==2.0.0 -U

  # !pip install -q git+https://github.com/invoke-ai/GFPGAN@basicsr-1.4.2#egg=gfpgan
  # !pip install -q git+https://github.com/openai/CLIP.git@main#egg=clip
  # !pip install -q git+https://github.com/Birch-san/k-diffusion.git@mps#egg=k-diffusion
  # !pip install -q git+https://github.com/invoke-ai/clipseg.git@relaxed-python-requirement#egg=clipseg
  # !pip install -q git+https://github.com/invoke-ai/PyPatchMatch@0.1.4#egg=pypatchmatch
  # %cd /content/InvokeAI/
  # !pip install -q -e .
  clear_output()
  print('[1;32mDone!')

  if DriveData == False :
    DriveDataPatch = "/content/db"
  if not os.path.exists(f"/content/drive/MyDrive/SD-Data/{DriveDataPatch}"):
    # %cd /content/InvokeAI/
    # !rm /content/InvokeAI/invokeai/configs/INITIAL_MODELS.yaml
    # !ln -s /content/command/INITIAL_MODELS.yaml /content/InvokeAI/invokeai/configs/
    # !python /content/InvokeAI/scripts/invokeai-model-install.py --root_dir /content/drive/MyDrive/SD-Data/{DriveDataPatch} --yes
    clear_output()
    print('[1;32mDone! Tất cả model đã được tải')
  if not os.path.isfile("/content/id_rsa") :
    id_rsa_file = "/content/InvokeAI/id_rsa"
    id_rsa_pub_file = "/content/InvokeAI/id_rsa.pub"
    if os.path.exists(id_rsa_file):
        os.remove(id_rsa_file)
    if os.path.exists(id_rsa_pub_file):
        os.remove(id_rsa_pub_file)

    def gen_key(path: Union[str, Path]) -> None:
        path = Path(path)
        arg_string = f'ssh-keygen -t rsa -b 4096 -N "" -q -f {path.as_posix()}'
        args = shlex.split(arg_string)
        subprocess.run(args, check=True)
        path.chmod(0o600)

    ssh_name = "id_rsa"
    ssh_path = Path(os.path.dirname(os.getcwd())) / ssh_name
    gen_key(ssh_path)

  clear_output()

#@markdown <br> [![](https://img.shields.io/badge/Tra%20cứu%20thông%20tin-Model-blue)](https://bit.ly/42Csmn7)

#Model
#@markdown ## ⚡️ Custom Model

SaveFromMyDrive = False  #@param {type:"boolean"}

if Version == "Kohya" :
  checkpointpatch = "/content/model"
if Version =="A-1.61" or Version =="A-1.7" or Version =="A-Forge" or Version =="A1111-update":
  checkpointpatch = "/content/SDVN/models/Stable-diffusion"
if Version == "ComfyUI" :
  checkpointpatch = "/content/ComfyUI/models/checkpoints"
if Version == "Fooocus" :
  checkpointpatch = "/content/Model"
if SaveFromMyDrive == True or Version =="AutoDrive" or Version == "Invoke" :
  checkpointpatch = "/content/drive/MyDrive/SD-Data/Model/New"

CheckpointDownloadLink = "" #@param {type:"string"}
CheckpointDownloadLink = CheckpointDownloadLink.replace("&", "\&")
if CheckpointDownloadLink != "" :
  # %cd {checkpointpatch}
  # !wget {CheckpointDownloadLink} --content-disposition
  if Version =="A-1.61" or Version =="A-1.7" or Version =="A-Forge" or Version =="A1111-update":
    # %cd /content/SDVN
  if Version == "ComfyUI" :
    # %cd /content/ComfyUI
  if Version == "Kohya" :
    # %cd /content/KohyaUI
  if Version == "Fooocus" :
    # %cd /content/Fooocus
  if Version == "AutoDrive" :
    # %cd /content/drive/MyDrive/{ForderNamePatch}

sdvnmodelUrl = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/109869 -d {checkpointpatch} -o SDVN1-Real.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110396 -d {checkpointpatch} -o SDVN2-RealRPG.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110538 -d {checkpointpatch} -o SDVN3-RealArt-plus.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110442 -d {checkpointpatch} -o SDVN4-3DCuteVN.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110455 -d {checkpointpatch} -o SDVN5-3DCuteWave.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/130249 -d {checkpointpatch} -o SDVN6-RealXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/155870 -d {checkpointpatch} -o SDVN7-NijiStyle.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/212479 -d {checkpointpatch} -o SDVN8-ArtXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/286354 -d {checkpointpatch} -o SDVN10-Anime.safetensors"]
sdvnmodelList = ["",
              "SDVN1-Real",
              "SDVN2-RealRPG",
              "SDVN3-RealArt-plus",
              "SDVN4-3DCuteVN",
              "SDVN5-3DCuteWave",
              "SDVN6-RealXL",
              "SDVN7-NijiStyle",
              "SDVN8-ArtXL",
              "SDVN10-Anime"]
#@markdown ## 👨🏻‍💻 SDVN Model
sdvnmodel = ""  #@param ["", "SDVN1-Real", "SDVN2-RealRPG", "SDVN3-RealArt-plus", "SDVN4-3DCuteVN", "SDVN5-3DCuteWave", "SDVN6-RealXL", "SDVN7-NijiStyle", "SDVN8-ArtXL", "SDVN10-Anime"]
# !{sdvnmodelUrl[sdvnmodelList.index(sdvnmodel)]}
baseUrl = ["",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -d {checkpointpatch} -o StableDiffusion-v14.ckpt",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned.safetensors -d {checkpointpatch} -o StableDiffusion-v15.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-nonema-pruned.safetensors -d {checkpointpatch} -o StableDiffusion-v21-512.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-nonema-pruned.safetensors -d {checkpointpatch} -o StableDiffusion-v21-768.safetensors",
          f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M  https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors -d {checkpointpatch} -o SDXL-1.0.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-cascade/resolve/main/comfyui_checkpoints/stable_cascade_stage_c.safetensors -d {checkpointpatch} -o ComfyUI-cascade_stage_c.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-cascade/resolve/main/comfyui_checkpoints/stable_cascade_stage_b.safetensors -d {checkpointpatch} -o ComfyUI-cascade_stage_b.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-video-diffusion-img2vid-xt/resolve/main/svd_xt.safetensors -d {checkpointpatch} -o SD-img-to-video-25f.safetensors"]
baseList = ["",
            "StableDiffusion-v14",
            "StableDiffusion-v15",
            "StableDiffusion-v21-512",
            "StableDiffusion-v21-768",
            "SDXL-Base-1.0",
            "ComfyUI-cascade_stage_c",
            "ComfyUI-cascade_stage_b",
            "SD-img-to-video-25f"]
#@markdown ## 🎇 Base Model
basemodelName = ""  #@param ["", "StableDiffusion-v14","StableDiffusion-v15", "StableDiffusion-v21-512",  "StableDiffusion-v21-768", "SDXL-Base-1.0", "ComfyUI-cascade_stage_c", "ComfyUI-cascade_stage_b", "SD-img-to-video-25f"]
# !{baseUrl[baseList.index(basemodelName)]}
inpaintUrl = ["",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/runwayml/stable-diffusion-inpainting/resolve/main/sd-v1-5-inpainting.ckpt -d {checkpointpatch} -o SD-v1-5-inpainting.ckpt",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-inpainting/resolve/main/512-inpainting-ema.ckpt -d {checkpointpatch} -o SD-v2-512-inpainting.ckpt",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/wangqyqq/sd_xl_base_1.0_inpainting_0.1.safetensors/resolve/main/sd_xl_base_1.0_inpainting_0.1.safetensors -d {checkpointpatch} -o SDXL-Base-inpainting.ckpt",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/131004 -d {checkpointpatch} -o DreamShaperv8-inpainting.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/130090 -d {checkpointpatch} -o RealisticVisionv5-inpainting.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/153048 -d {checkpointpatch} -o SDVN1-Real-inpainting.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/153052 -d {checkpointpatch} -o SDVN5-3DCuteWave-inpainting.safetensors"]
inpaintList = ["",
            "SD-v1-5-inpainting",
            "SD-v2-512-inpainting",
            "SDXL-Base-inpainting",
            "DreamShaperv8-inpainting",
            "RealisticVisionv5-inpainting",
            "SDVN1-Real-inpainting",
            "SDVN5-3DCuteWave-inpainting"]
#@markdown ## 🎇 Inpaint Model
inpaintmodelName = ""  #@param ["", "SD-v1-5-inpainting","SD-v2-512-inpainting", "SDXL-Base-inpainting","DreamShaperv8-inpainting",  "RealisticVisionv5-inpainting", "SDVN1-Real-inpainting", "SDVN5-3DCuteWave-inpainting"]
# !{inpaintUrl[inpaintList.index(inpaintmodelName)]}

sdxlmodelUrl = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/163192 -d {checkpointpatch} -o XXMix_9realisticSDXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/338512 -d {checkpointpatch} -o LEOSAM-HelloWorldXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/357609 -d {checkpointpatch} -o JuggernautXL-v9.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/362861 -d {checkpointpatch} -o ZavyChromaXL-v5.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/144566 -d {checkpointpatch} -o Samaritan3dCartoon-v4.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/136754 -d {checkpointpatch} -o DucHaiten-AIart-SDXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/149020 -d {checkpointpatch} -o Lah-Mysterious-SDXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/150238 -d {checkpointpatch} -o Copax-TimeLessXL-v5.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/154625 -d {checkpointpatch} -o Niji-SpecialEdition.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/146761 -d {checkpointpatch} -o CounterfeitXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/133832 -d {checkpointpatch} -o CrystalClearXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/152076 -d {checkpointpatch} -o JuggernautXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/133462 -d {checkpointpatch} -o AnimagineXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/131579 -d {checkpointpatch} -o RunDiffusionXL.safetensors"
            ]
sdxlmodelList = ["",
              "XXMix_9realisticSDXL",
              "LEOSAM-HelloWorldXL",
              "JuggernautXL-v9",
              "ZavyChromaXL-v5",
              "Samaritan3dCartoon-v4",
              "DucHaiten-AIart-SDXL",
              "Lah-Mysterious-SDXL",
              "Copax-TimeLessXL-v5",
              "Niji-SpecialEdition",
              "CounterfeitXL",
              "CrystalClearXL",
              "JuggernautXL",
              "AnimagineXL",
              "RunDiffusionXL"
              ]
#@markdown ## 🎨 SDXLModel
sdxlmodel = ""  #@param ["", "XXMix_9realisticSDXL", "LEOSAM-HelloWorldXL", "JuggernautXL-v9", "ZavyChromaXL-v5", "Samaritan3dCartoon-v4", "DucHaiten-AIart-SDXL", "Lah-Mysterious-SDXL","Copax-TimeLessXL-v5","Niji-SpecialEdition","CounterfeitXL","CrystalClearXL","JuggernautXL","AnimagineXL", "RunDiffusionXL"]
# !{sdxlmodelUrl[sdxlmodelList.index(sdxlmodel)]}
modelUrl = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9474 -d {checkpointpatch} -o Chilloutmix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/130072 -d {checkpointpatch} -o RealisticVision51.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15236 -d {checkpointpatch} -o Deliberate.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/128713 -d {checkpointpatch} -o DreamShaperv8.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/79290 -d {checkpointpatch} -o A-ZovyaRPGv3.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/70458 -d {checkpointpatch} -o HenmixRealv4.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/77784 -d {checkpointpatch} -o Fantasticv65.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/77903 -d {checkpointpatch} -o XXMix_9realisticv3.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/94640 -d {checkpointpatch} -o MajicmixRealv6.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46846 -d {checkpointpatch} -o ReVAnimatedv122.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88158 -d {checkpointpatch} -o RunDiffusionFXv1.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/113479 -d {checkpointpatch} -o RBeautifulRealAsiansv6.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/113623 -d {checkpointpatch} -o LEOSAM-MoonFilm-v2.safetensors"]
modelList = ["",
             "Chilloutmix",
             "RealisticVision51",
             "Deliberate",
             "DreamShaperv8",
             "A-ZovyaRPGv3",
             "HenmixRealv4",
             "Fantasticv65",
             "XXMix_9realisticv3",
             "MajicmixRealv6",
             "ReVAnimatedv122",
             "RunDiffusionFXv1",
             "RBeautifulRealAsiansv6",
             "LEOSAM-MoonFilm-v2"]
#@markdown ## 🏞️ Realistic model 1
modelName = ""  #@param ["", "Chilloutmix", "RealisticVision51", "Deliberate", "DreamShaperv8", "A-ZovyaRPGv3", "HenmixRealv4", "Fantasticv65", "XXMix_9realisticv3", "MajicmixRealv6", "ReVAnimatedv122", "RunDiffusionFXv1", "RBeautifulRealAsiansv6", "LEOSAM-MoonFilm-v2"]
# !{modelUrl[modelList.index(modelName)]}

model2Url = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7425 -d {checkpointpatch} -o Counterfeit.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/OtakupastelwaveMixPro/resolve/main/OtakuMix.safetensors -d {checkpointpatch} -o OtakupastelwaveMixPro.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/xyn-ai/anything-v4.0/resolve/main/anything-v4.5-pruned-fp16.ckpt -d {checkpointpatch} -o AnythingV45.ckpt",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/Dalcefov4.safetensors -d {checkpointpatch} -o Dalcefov4.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/Camelliamix.safetensors -d {checkpointpatch} -o Camelliamix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/27424 -d {checkpointpatch} -o FishMix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/19348 -d {checkpointpatch} -o OrientalMix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/36473 -d {checkpointpatch} -o ThreeDelicacyv2.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/50765 -d {checkpointpatch} -o GODofSIMP.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17028 -d {checkpointpatch} -o TheoldfishSpread.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/40101 -d {checkpointpatch} -o Theoldfish.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14835 -d {checkpointpatch} -o NightSkyYOZORA.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/76907 -d {checkpointpatch} -o GhostMixv2.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/125771 -d {checkpointpatch} -o ToonYou-beta6.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88516 -d {checkpointpatch} -o ComicsArthemyv3.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88516 -d {checkpointpatch} -o MeinaMix-v11.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/116017 -d {checkpointpatch} -o ManmaruMix-v2.safetensors"]
model2List = ["",
             "Counterfeit",
             "OtakupastelwaveMix",
             "AnythingV45",
             "Dalcefov4",
             "Camelliamix",
             "OrientalMix",
             "FishMix",
             "ThreeDelicacyv2",
             "GODofSIMP",
             "TheoldfishSpread",
             "Theoldfish",
             "NightSkyYOZORA",
             "GhostMixv2",
             "ToonYou-beta6",
             "ComicsArthemyv3",
             "MeinaMix-v11",
             "ManmaruMix-v2"]
#@markdown ## 🌇 Anime/Paint model 2
model2Name = ""  #@param ["", "Counterfeit", "OtakupastelwaveMix", "AnythingV45", "Dalcefov4", "Camelliamix", "OrientalMix", "FishMix", "ThreeDelicacyv2", "GODofSIMP", "TheoldfishSpread", "Theoldfish", "NightSkyYOZORA", "GhostMixv2", "ToonYou-beta6", "ComicsArthemyv3", "MeinaMix-v11", "ManmaruMix-v2"]
# !{model2Url[model2List.index(model2Name)]}

if Version == "Fooocus" :
  # !ln -s /content/DownloadModel /content/Fooocus/models/checkpoints

# %%
#@title # ⌛️ 2.RUN
#@markdown ##### 🔸 `Automatic / Fooocus / Kohya sử dụng link sever là gradio (Xuất hiện cuối đoạn chạy code của phần 2)`
#@markdown ##### 🔸 `ComfyUI / Invoke sử dụng link sever CloudFlare ( Xuất hiện đầu đoạn chạy code phần 2)`
SDXLConfig = False  #@param {type:"boolean"}
CommandLine = "" #@param {type:"string"}

if Version != "AutoDrive" and Version != "Kohya" and Version != "Fooocus" and Version != "Invoke":
  print('[1;32mCài đặt Extension/Note tuỳ chọn...')
  with capture.capture_output() as cap:
    def inf(msg, style, wdth):
        inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth))
        display(inf)
    if Version != "ComfyUI" :
      # %cd /content/SDVN/extensions
      if os.path.isfile("/content/drive/MyDrive/SD-Data/wildcards/MyExtensionList.txt"):
        with open("/content/drive/MyDrive/SD-Data/wildcards/MyExtensionList.txt", "r") as file:
          lists = file.readlines()
        for list in lists :
          # !git clone {list}
      # %cd /content/SDVN
    else :
      # %cd /content/ComfyUI/custom_nodes
      if os.path.isfile("/content/drive/MyDrive/SD-Data/wildcards/ComfyCustomNote.txt"):
        with open("/content/drive/MyDrive/SD-Data/wildcards/ComfyCustomNote.txt", "r") as file:
          notes = file.readlines()
        for note in notes :
          # !git clone {note}
          last_segment = note.rsplit('/', 1)[-1]
          # !pip install -r {last_segment}/requirements.txt
      # %cd /content/ComfyUI

  clear_output()
  inf('\u2714 Done','success', '150px')

if Version != "ComfyUI" and Version != "Kohya" and Version != "Fooocus" and Version != "Invoke":
  if os.path.exists("extensions/sd-webui-tunnels"):
    tunnels = True
  else :
    tunnels = False
  token = False
  ngrok = False
  if os.path.isfile("/content/drive/MyDrive/SD-Data/wildcards/Ngroktoken.txt"):
    with open("/content/drive/MyDrive/SD-Data/wildcards/Ngroktoken.txt", "r") as file:
        lists = file.readlines()
    if Ngroktoken != "" :
      token = Ngroktoken
    else :
      if lists !=[]:
        token = lists[0]
    if token :
      ngrok = f"--ngrok {token}"
  # !python launch.py --enable-insecure-extension-access --disable-safe-unpickle --theme dark --xformers --share --no-half-vae \
    --ui-settings-file /content/drive/MyDrive/SD-Data/Setting15/{"configxl.json" if SDXLConfig else "config.json"} \
    --styles-file /content/drive/MyDrive/SD-Data/Setting15/styles.csv \
    --ckpt-dir /content/drive/MyDrive/SD-Data/Model \
    --lora-dir /content/drive/MyDrive/SD-Data/Lora \
    --embeddings-dir /content/drive/MyDrive/SD-Data/Embeddings \
    --hypernetwork-dir /content/drive/MyDrive/SD-Data/Hypernetworks \
    {"--api" if PhotoshopAPI else "" } {ngrok if ngrok else ""} {"--cloudflared --localhostrun" if tunnels else ""}\
    {"--controlnet-dir /content/drive/MyDrive/SD-Data/ControlnetModel" if Controlnet == "drive" else ""} {CommandLine}

if Version == "ComfyUI" :
  print("Truy cập đường link bên dưới để sử dụng (Link sử dụng được sau khi hiện thông báo - Import times for custom nodes:- )")
  import atexit, requests, subprocess, time, re, os
  from random import randint
  from threading import Timer
  from queue import Queue
  def cloudflared(port, metrics_port, output_queue):
      atexit.register(lambda p: p.terminate(), subprocess.Popen(['/content/cloudflared-linux-amd64', 'tunnel', '--url', f'http://127.0.0.1:{port}', '--metrics', f'127.0.0.1:{metrics_port}'], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT))
      attempts, tunnel_url = 0, None
      while attempts < 10 and not tunnel_url:
          attempts += 1
          time.sleep(3)
          try:
              tunnel_url = re.search("(?P<url>https?:\/\/[^\s]+.trycloudflare.com)", requests.get(f'http://127.0.0.1:{metrics_port}/metrics').text).group("url")
          except:
              pass
      if not tunnel_url:
          raise Exception("Can't connect to Cloudflare Edge")
      output_queue.put(tunnel_url)
  output_queue, metrics_port = Queue(), randint(8100, 9000)
  thread = Timer(2, cloudflared, args=(8188, metrics_port, output_queue))
  thread.start()
  thread.join()
  tunnel_url = output_queue.get()
  os.environ['webui_url'] = tunnel_url
  print(tunnel_url)
  # !python main.py --dont-print-server --preview-method auto

if Version == "Kohya" :
  # !python kohya_gui.py --share --headless
if Version == "Fooocus" :
  # !python entry_with_update.py --share --theme dark --disable-preset-download {CommandLine}
if Version == "Invoke" :
  import threading
  def tunnel():
    # !ssh -R 80:127.0.0.1:9090 -o StrictHostKeyChecking=no -i /content/id_rsa remote.moe
  threading.Thread(target=tunnel, daemon=True).start()

  # %cd /content/InvokeAI/
  # !python /content/InvokeAI/scripts/invokeai-web.py --root /content/drive/MyDrive/SD-Data/{DriveDataPatch}
